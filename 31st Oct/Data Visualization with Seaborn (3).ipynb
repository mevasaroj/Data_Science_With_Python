# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
heart = pd.read_csv('clevelanda.csv')

# %%
heart.head()
# Out:
#    age  gender  cp  trestbps  chol  fps  restecg  thalach  exang  oldpeak  \
# 0   63       1   1       145   233    1        2      150      0      2.3
# 1   67       1   4       160   286    0        2      108      1      1.5
# 2   67       1   4       120   229    0        2      129      1      2.6
# 3   37       1   3       130   250    0        0      187      0      3.5
# 4   41       0   2       130   204    0        2      172      0      1.4
#
#    slope ca thal  class
# 0      3  0    6      0
# 1      2  3    3      2
# 2      2  2    7      1
# 3      3  0    3      0
# 4      1  0    3      0

# %%
sns.lineplot(x = heart['age'], y = heart['trestbps'])
# Out:
# <AxesSubplot:xlabel='age', ylabel='trestbps'>

# %%
sns.lineplot(x="age", y="trestbps", hue="gender",
                  data=heart)
# Out:
# <AxesSubplot:xlabel='age', ylabel='trestbps'>

# %%
df = pd.DataFrame(np.random.rand(10,4), columns = ['a','b','c','d'])

# %%
sns.lineplot(x="age", y="thalach",
                  hue="gender", style="gender",
                  markers=True, dashes=False, data=heart)
# Out:
# <AxesSubplot:xlabel='age', ylabel='thalach'>

# %%
sns.lineplot(x="age", y="thalach",
                  hue="gender", data=heart)

# %%
sns.lineplot(x="age", y="thalach",
                  hue="gender", style="gender",data=heart)

# %%
plt.figure(1)
plt.figure(figsize = (14,14))
plt.subplot(221)
plt.title('Lineplot different features')
sns.lineplot(x="age", y="thalach",
                  hue="gender", style="gender",
                  markers=True, dashes=True, data=heart)

plt.subplot(222)
sns.lineplot(x="age", y="thalach",
                  hue="gender",
                  markers=True, dashes=True, data=heart)

plt.subplot(223)
sns.lineplot(x="age", y="thalach",
                  hue="gender", style="gender",
                 dashes=True, data=heart)

plt.subplot(224)
sns.lineplot(x="age", y="thalach",
                  hue="gender", style="gender",
                  markers=True, data=heart)
# Out:
# <AxesSubplot:xlabel='age', ylabel='thalach'>

# %%
heart['age'].hist()
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(heart['thalach'])
# Out:
# <AxesSubplot:xlabel='thalach'>

# %%
heart['thalach'].describe()
# Out:
# count    303.000000
# mean     149.607261
# std       22.875003
# min       71.000000
# 25%      133.500000
# 50%      153.000000
# 75%      166.000000
# max      202.000000
# Name: thalach, dtype: float64

# %%
df.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df.plot.barh(stacked = True)
# Out:
# <AxesSubplot:>

# %%
df.plot.hist(alpha = 0.3)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.plot.box()
# Out:
# <AxesSubplot:>

# %%
userspecific = dict(boxes = 'DarkGreen', whiskers = 'DarkOrange', medians = 'DarkBlue', caps = 'Gray')

# %%
df.plot.box(color = userspecific)
# Out:
# <AxesSubplot:>

# %%
df.plot.area(stacked= False) #When we need to study about the trend
# Out:
# <AxesSubplot:>

# %%
#Matplotlib Commands
heart = pd.read_csv('clevelanda.csv')

# %%
sns.lineplot(x = heart['age'], y= heart['thalach'])
plt.ylabel('Thalach')
plt.xlabel('Age')
plt.show()

# %%
sns.barplot(x = heart['thal'], y= heart['thalach'])
# Out:
# <AxesSubplot:xlabel='thal', ylabel='thalach'>

# %%
#Subplotting
plt.figure(1)
plt.subplot(221)
plt.title('Count of heart pat')
sns.countplot(heart['class'])

plt.subplot(222)
sns.distplot(heart['age'])

plt.subplot(223)
sns.scatterplot(heart['age'],heart['thalach'])

plt.subplot(224)
sns.boxplot(x = heart['age'], y = heart['thalach'])
# Out:
# <AxesSubplot:xlabel='age', ylabel='thalach'>

# %%
df = pd.DataFrame(np.random.rand(10,4), columns = ['a','b','c','d'])

# %%
sns.pairplot(df)

# %%
d = heart.corr()

# %%
plt.figure(figsize = (14,14))
sns.heatmap(d, annot = True)
# Out:
# <AxesSubplot:>

# %%
d = heart.corr()

# %%
df1 = np.random.randn(100000)

# %%
sns.distplot(df1, hist = False)
# Out:
# <AxesSubplot:>

# %%
sns.distplot(df1, kde = False)
# Out:
# <AxesSubplot:>

# %%
heart.head()
# Out:
#    age  gender  cp  trestbps  chol  fps  restecg  thalach  exang  oldpeak  \
# 0   63       1   1       145   233    1        2      150      0      2.3
# 1   67       1   4       160   286    0        2      108      1      1.5
# 2   67       1   4       120   229    0        2      129      1      2.6
# 3   37       1   3       130   250    0        0      187      0      3.5
# 4   41       0   2       130   204    0        2      172      0      1.4
#
#    slope ca thal  class
# 0      3  0    6      0
# 1      2  3    3      2
# 2      2  2    7      1
# 3      3  0    3      0
# 4      1  0    3      0

# %%
sns.countplot(x = 'gender', data = heart, hue = 'class')
plt.legend(loc = 'lower right')

# %%
sns.scatterplot(x = 'age', y= 'thalach', data = heart, hue = 'class')
plt.savefig('img.png')

# %%
sns.lmplot(x = 'age', y = 'thalach', data =heart, row = 'gender')

# %%
sns.lmplot(x = 'age', y = 'thalach', data =heart, col = 'gender')

# %%
plt.figure(figsize = (14,14))
plt.subplot(221)
plt.title('Count of heart pat')
sns.countplot(heart['class'])


plt.subplot(223)
plt.title('Distribution of Age')
sns.distplot(heart['age'])

plt.subplot(222)
plt.title('Correlation between')
sns.scatterplot(heart['age'],heart['thalach'])

plt.subplot(224)
plt.title('Outlier Study')
sns.boxplot(x = heart['age'], y = heart['thalach'])
plt.savefig('Dashboard.png')

# %%
sns.barplot(x = 'class', y ='trestbps', hue = 'gender' ,data=heart)
